# %%
#dichotomy
import math
 
def f(x):
    return x*x - 2


def MPD(f, a, b, eps=1e-3):
    i=0 
    while abs(b - a) > eps:
        c = (a + b) / 2.0
        
        fc = f(c)
        fa = f(a)
        
        print("%.f %.8f %.8f %.8f %.8f %.8f %.8f " % (i,a,c,b,fa,fc,f(b))) 
        if (fc < 0 and fa < 0) or (fc > 0 and fa > 0):
            a = c
        else:
            b = c
        i+=1
    return c
print("i       a          c         b          fa          fc          fb")
MPD(f, 0, 8)
# Out:
# i       a          c         b          fa          fc          fb
# 0 0.00000000 4.00000000 8.00000000 -2.00000000 14.00000000 62.00000000
# 1 0.00000000 2.00000000 4.00000000 -2.00000000 2.00000000 14.00000000
# 2 0.00000000 1.00000000 2.00000000 -2.00000000 -1.00000000 2.00000000
# 3 1.00000000 1.50000000 2.00000000 -1.00000000 0.25000000 2.00000000
# 4 1.00000000 1.25000000 1.50000000 -1.00000000 -0.43750000 0.25000000
# 5 1.25000000 1.37500000 1.50000000 -0.43750000 -0.10937500 0.25000000
# 6 1.37500000 1.43750000 1.50000000 -0.10937500 0.06640625 0.25000000
# 7 1.37500000 1.40625000 1.43750000 -0.10937500 -0.02246094 0.06640625
# 8 1.40625000 1.42187500 1.43750000 -0.02246094 0.02172852 0.06640625
# 9 1.40625000 1.41406250 1.42187500 -0.02246094 -0.00042725 0.02172852
# 10 1.41406250 1.41796875 1.42187500 -0.00042725 0.01063538 0.02172852
# 11 1.41406250 1.41601562 1.41796875 -0.00042725 0.00510025 0.01063538
# ...

# %%
#Newton
import  math
def F(x):
    return x*x-2
 
 
 
def F1(x):
    return 2*x
 
def f2(x):
    return 2
 
def Method(a, b):
    print("n    an-1       Fan-1        F'an-1         F''      an")
    i=0
    try:
        if f(a)*f2(a)>0:
            a0=a
        else:
            a0=b
        
        an = a0 - F(a0) / F1(a0)
        while abs(an - a0) > math.pow(10, -10):
            print("%.f %.8f %.8f %.8f %.8f %.8f" % (i,a0,F(a0),F1(a0),f2(a0), an))
            i+=1
            a0=an
            an = a0 - F(an) / F1(an)
            
            
           
        #print(an1)
        return an
    except ValueError:
        print("Value not invalidate")
if __name__ == '__main__':
    a=float(input())
    b=float(input())
    Method(a, b)
# Out:
# 0
# 8
# n    an-1       Fan-1        F'an-1         F''      an
# 0 8.00000000 62.00000000 16.00000000 2.00000000 4.12500000
# 1 4.12500000 15.01562500 8.25000000 2.00000000 2.30492424
# 2 2.30492424 3.31267576 4.60984848 2.00000000 1.58631586
# 3 1.58631586 0.51639801 3.17263172 2.00000000 1.42354941
# 4 1.42354941 0.02649292 2.84709882 2.00000000 1.41424418
# 5 1.41424418 0.00008659 2.82848835 2.00000000 1.41421356
# 6 1.41421356 0.00000000 2.82842713 2.00000000 1.41421356

# %%
#secand
def f(x):
    return x*x-2

def secand(a,b,eps):
    c0=0.
    for i in range(0,20):
        
        cn=(a*f(b)-b*f(a))/(f(b)-f(a))
        print("%.8f \t     %.8f \t %.8f \t        %.8f" % (a,b,f(a),f(b)))  
        if (f(a)*f(cn)<0):
            b=cn
        else:
            a=cn
        #if (abs(cn-c0)<eps) and abs(f(cn))<eps:
         #   break
        #c0=cn
        print("\t   %.8f \t\t\t\t     %.8f\n ----------------------------------------------------------------" % (cn,f(cn))) 
print("    a          c        b                      fa       fc          fb")
secand(0.,8.,0.000001)
# Out:
#     a          c        b                      fa       fc          fb
# 0.00000000 	     8.00000000 	 -2.00000000 	        62.00000000
# 	   0.25000000 				     -1.93750000
#  ----------------------------------------------------------------
# 0.25000000 	     8.00000000 	 -1.93750000 	        62.00000000
# 	   0.48484848 				     -1.76492195
#  ----------------------------------------------------------------
# 0.48484848 	     8.00000000 	 -1.76492195 	        62.00000000
# 	   0.69285714 				     -1.51994898
#  ----------------------------------------------------------------
# 0.69285714 	     8.00000000 	 -1.51994898 	        62.00000000
# 	   0.86770748 				     -1.24708373
#  ----------------------------------------------------------------
# 0.86770748 	     8.00000000 	 -1.24708373 	        62.00000000
# 	   1.00833951 				     -0.98325143
#  ----------------------------------------------------------------
# 1.00833951 	     8.00000000 	 -0.98325143 	        62.00000000
# ...

# %%
#iteration
from math import sqrt,pow
def f(x):
    return x*x*x-x*x+x-5
def g(x):
    return pow(x*x-x+5,1./3.)
def g1(x):
    return (2*x-1)/3/pow(pow(x*x-x+5,2),1./3.)
def method(a,b,eps):
    i=0
    x0=b
    x1=b
    for i in range(20):
        print("%.f %.10f\t %.10f\t %.10f \t%.10f"%(i,x1, f(x1),g(x1),g1(x1)))
        x1=g(x0)
        x0=x1
        i+=1
    return x1
print("i     x              f(x)           g(x)         g'(x)")        
method(0,8,0.01)
# Out:
# i     x              f(x)           g(x)         g'(x)
# 0 8.0000000000	 451.0000000000	 3.9364971831 	0.3226637035
# 1 3.9364971831	 44.4404871105	 2.5488788043 	0.3526357685
# 2 2.5488788043	 7.6116085349	 2.0760625983 	0.3169159679
# 3 2.0760625983	 1.7139310408	 1.9340111227 	0.2809081043
# 4 1.9340111227	 0.4275854137	 1.8951295294 	0.2661849294
# 5 1.8951295294	 0.1100014964	 1.8848646465 	0.2617959567
# 6 1.8848646465	 0.0285363148	 1.8821834155 	0.2606106652
# 7 1.8821834155	 0.0074190950	 1.8814850755 	0.2602992179
# 8 1.8814850755	 0.0019299803	 1.8813033265 	0.2602179742
# 9 1.8813033265	 0.0005021340	 1.8812560340 	0.2601968214
# 10 1.8812560340	 0.0001306482	 1.8812437288 	0.2601913167
# 11 1.8812437288	 0.0000339931	 1.8812405271 	0.2601898843
# 12 1.8812405271	 0.0000088446	 1.8812396941 	0.2601895116
# 13 1.8812396941	 0.0000023013	 1.8812394773 	0.2601894147
# 14 1.8812394773	 0.0000005988	 1.8812394209 	0.2601893894
# ...

# %%
#dichotomy
import math
 
def f(x):
    return x*x*x+7*x+1.2


def MPD(f, a, b, eps=1e-6):
    i=0 
    while abs(b - a) > eps:
        c = (a + b) / 2.0
        
        fc = f(c)
        fa = f(a)
        
        print("%.f %.8f %.8f %.8f %.8f %.8f %.8f " % (i,a,c,b,fa,fc,f(b))) 
        if (fc < 0 and fa < 0) or (fc > 0 and fa > 0):
            a = c
        else:
            b = c
        i+=1
    return c
print("i       a          c         b          fa          fc          fb")
MPD(f, -1,0)
# Out:
# i       a          c         b          fa          fc          fb
# 0 -1.00000000 -0.50000000 0.00000000 -6.80000000 -2.42500000 1.20000000
# 1 -0.50000000 -0.25000000 0.00000000 -2.42500000 -0.56562500 1.20000000
# 2 -0.25000000 -0.12500000 0.00000000 -0.56562500 0.32304687 1.20000000
# 3 -0.25000000 -0.18750000 -0.12500000 -0.56562500 -0.11909180 0.32304687
# 4 -0.18750000 -0.15625000 -0.12500000 -0.11909180 0.10243530 0.32304687
# 5 -0.18750000 -0.17187500 -0.15625000 -0.11909180 -0.00820236 0.10243530
# 6 -0.17187500 -0.16406250 -0.15625000 -0.00820236 0.04714651 0.10243530
# 7 -0.17187500 -0.16796875 -0.16406250 -0.00820236 0.01947976 0.04714651
# 8 -0.17187500 -0.16992188 -0.16796875 -0.00820236 0.00564065 0.01947976
# 9 -0.17187500 -0.17089844 -0.16992188 -0.00820236 -0.00128037 0.00564065
# 10 -0.17089844 -0.17041016 -0.16992188 -0.00128037 0.00218026 0.00564065
# 11 -0.17089844 -0.17065430 -0.17041016 -0.00128037 0.00044998 0.00218026
# ...

# %%
#secand
def f(x):
    return x*x*x+x-8

def secand(a,b,eps):
    c0=0.
    for i in range(0,10):
        
        cn=(a*f(b)-b*f(a))/(f(b)-f(a))
        print("%.8f \t     %.8f \t %.8f \t        %.8f" % (a,b,f(a),f(b)))  
        if (f(a)*f(cn)<0):
            b=cn
        else:
            a=cn
        #if (abs(cn-c0)<eps) and abs(f(cn))<eps:
         #   break
        #c0=cn
        print("\t   %.8f \t\t\t\t     %.8f\n ----------------------------------------------------------------" % (cn,f(cn))) 
print("    a          c        b                      fa       fc          fb")
secand(1.,2.,0.000001)
# Out:
#     a          c        b                      fa       fc          fb
# 1.00000000 	     2.00000000 	 -6.00000000 	        2.00000000
# 	   1.75000000 				     -0.89062500
#  ----------------------------------------------------------------
# 1.75000000 	     2.00000000 	 -0.89062500 	        2.00000000
# 	   1.82702703 				     -0.07430604
#  ----------------------------------------------------------------
# 1.82702703 	     2.00000000 	 -0.07430604 	        2.00000000
# 	   1.83322329 				     -0.00584926
#  ----------------------------------------------------------------
# 1.83322329 	     2.00000000 	 -0.00584926 	        2.00000000
# 	   1.83370962 				     -0.00045830
#  ----------------------------------------------------------------
# 1.83370962 	     2.00000000 	 -0.00045830 	        2.00000000
# 	   1.83374772 				     -0.00003590
#  ----------------------------------------------------------------
# 1.83374772 	     2.00000000 	 -0.00003590 	        2.00000000
# ...

# %%
#Newton
import  math
def F(x):
    return 0.5*x*x*x+4*x-16.75
 
 
 
def F1(x):
    return 1.5*x*x+4
 
def f2(x):
    return 3*x
 
def Method(a, b):
    print("n    an-1       Fan-1        F'an-1         F''      an")
    i=0
    try:
        if f(a)*f2(a)>0:
            a0=a
        else:
            a0=b
        
        an = a0 - F(a0) / F1(a0)
        while abs(an - a0) > math.pow(10, -10):
            print("%.f %.8f %.8f %.8f %.8f %.8f" % (i,a0,F(a0),F1(a0),f2(a0), an))
            i+=1
            a0=an
            an = a0 - F(an) / F1(an)         
        #print(an1)
        return an
    except ValueError:
        print("Value not invalidate")
if __name__ == '__main__':
    a=float(input())
    b=float(input())
    Method(a, b)
# Out:
# 2
# 3
# n    an-1       Fan-1        F'an-1         F''      an
# 0 2.00000000 -4.75000000 10.00000000 6.00000000 2.47500000
# 1 2.47500000 0.73046094 13.18843750 7.42500000 2.41961353
# 2 2.41961353 0.01130374 12.78179449 7.25884060 2.41872917
# 3 2.41872917 0.00000284 12.77537621 7.25618752 2.41872895

# %%
#iteration
#3*x*x*x+10*x+50=0 (-2;-3)c
# Out:
# i     x              f(x)           g(x)         g'(x)
# -2.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-f47da57a8d01> in <module>()
#      13 x0 = -2.0
#      14 x1 = -2.0
# ---> 15 print("%.f %.8f\t %.8f\t %.8f \t%.8f"%(0, x1, f(x1), g(x1), g1(x1)))
#      16 for i in range(1, 20):
#      17     x1 = g(x0)
#
# <ipython-input-5-f47da57a8d01> in g1(x)
#       8 def g1(x):
#       9     print x
# ---> 10     return -10/ (9 * (pow(1/3 * (-10 * x - 50),2./3.)))
#      11 print("i     x              f(x)           g(x)         g'(x)")
#      12
#
# ZeroDivisionError: float division by zero
